# %%
import pandas as pd
import json

# %%
with open('C:/Users/YunSeog/Desktop/Melonplay/Hunchbrown-Melon-Playlist-Continuation/res/genre_gn_all.json', encoding = 'UTF-8') as f:
    genre_data = json.load(f)

# %%
print(pd.Series(genre_data)[100])
# Out:
# R&B/Soul

# %%
with open('C:/Users/YunSeog/Desktop/Melonplay/Hunchbrown-Melon-Playlist-Continuation/res/song_meta.json', encoding = 'UTF-8') as f:
    song_meta_data = json.load(f)

# %%
song_data = (pd.DataFrame(song_meta_data))

# %%
song_data.head(10)
# Out:
#      song_gn_dtl_gnr_basket issue_date  \
# 0                  [GN0901]   20140512
# 1          [GN1601, GN1606]   20080421
# 2                  [GN0901]   20180518
# 3          [GN1102, GN1101]   20151016
# 4          [GN1802, GN1801]   20110824
# 5                  [GN1701]   20100602
# 6  [GN1601, GN1602, GN1614]   20170208
# 7  [GN1601, GN1602, GN1614]   20190315
# 8                  [GN0301]   20070625
# 9          [GN0105, GN0101]   20170320
#
#                                           album_name  album_id  \
# 0                       불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
# 1                      Bach : Partitas Nos. 2, 3 & 4    376431
# 2                                                Hit   4698747
# 3  Feeling Right (Everything Is Nice) (Feat. Popc...   2644882
# 4                                            그남자 그여자   2008470
# 5                                        Bye, Lupita    911754
# 6    Sibelius: Symphony No. 2; Tapiola; Valse triste  10038397
# 7  Celebrating John Williams (Live At Walt Disney...  10261160
# 8                                        Sexualmetro    353020
# 9                                  Pastel Reflection  10047088
#
#    artist_id_basket                                          song_name  \
# 0            [2727]                                           Feelings
# 1           [29966]  Bach : Partita No. 4 In D Major, BWV 828 - II....
# 2            [3361]                    Solsbury Hill (Remastered 2002)
# 3          [838543]  Feeling Right (Everything Is Nice) (Feat. Popc...
# 4          [560160]                                            그남자 그여자
# 5          [475840]                                Para Los Enamorados
# 6  [162097, 100237]  Sibelius : Valse Triste Op.44 (시벨리우스 : 슬픈 왈츠 작...
# 7  [105210, 261542]  Superman March (From &#34;Superman&#34; / Live...
# 8          [224583]                      Lovers’ Leap (Feat. Qypthone)
# 9          [753752]                                       사랑, 그대라는 멜로디
#
#   song_gn_gnr_basket                                 artist_name_basket  id
# 0           [GN0900]                                  [Various Artists]   0
# 1           [GN1600]                                   [Murray Perahia]   1
# 2           [GN0900]                                    [Peter Gabriel]   2
# 3           [GN1100]                                           [Matoma]   3
# 4           [GN1800]                                         [Jude Law]   4
# 5           [GN1700]                                      [Bye, Lupita]   5
# 6           [GN1600]        [Herbert Blomstedt, San Francisco Symphony]   6
# 7           [GN1600]  [Los Angeles Philharmonic Orchestra, Gustavo D...   7
# 8           [GN0300]                                              [애플스]   8
# 9           [GN0100]                                               [진호]   9

# %%
with open('C:/Users/YunSeog/Desktop/Melonplay/Hunchbrown-Melon-Playlist-Continuation/res/train.json', encoding = 'UTF-8') as f:
    train_data = json.load(f)

# %%
trainee_data = (pd.DataFrame(train_data))

# %%
trainee_data.loc[15]
# Out:
# tags                                                          [락]
# id                                                           8316
# plylst_title                                            걍게임할때듣는음악
# songs           [313901, 352039, 259807, 146310, 473162, 70359...
# like_cnt                                                        2
# updt_date                                 2013-10-17 11:59:02.000
# Name: 15, dtype: object

# %%
sample_songs = trainee_data.loc[15]['songs']
for song in sample_songs:
    print(song_data.loc[song]['song_name'], song_data.loc[song]['song_gn_gnr_basket'])
# Out:
# Just The Way You Are ['GN0900']
# Stronger (What Doesn`t Kill You) ['GN0900']
# Marry You ['GN1300']
# Temperamental ['GN1000']
# Misery ['GN1000']
# Give A Little More ['GN1000']
# Never Gonna Leave This Bed ['GN1000']
# Baby (Feat. Ludacris) ['GN0900']
# Vodka ['GN1000']
# I Got My Eye On You (Cristian Marchi & Paolo Sandrini Perfect Edit) (Feat. Luciana) ['GN1100']
# Grenade ['GN1300']
# Call You Mine (Feat. Geologic Of The Blue Scholars) ['GN1300']
# Lucky Strike ['GN0900', 'GN1000']
# Young Girls ['GN1300']
# Get Up (Rattle) (Feat. Far East Movement) ['GN2700', 'GN1100']
# The Bad Touch (Gordon & Doyle Edit) ['GN1100']
# Plug In Baby ['GN1000']
# Youth Gone Wild ['GN1000']
# The Kids Aren`t Alright ['GN1500']
# Smells Like Teen Spirit (Album Ver.) ['GN1000']
# In God We Trust ['GN1000']
# Stockholm Syndrome ['GN1000']
# Overnight Sensation ['GN1000']
# Since U Been Gone ['GN0900']
# American Idiot (Album Ver.) ['GN1000']
# So Sick ['GN1300']
# I.G.W.T (In God We Trust) ['GN1000']
# Gone ['GN0900']
# Starlight ['GN1000']
# You`re Gonna Go Far, Kid ['GN1000']
# Love The Way You Lie (Feat. Rihanna) ['GN1200']
# The Lazy Song ['GN1300']
# Play Hard (Feat. Ne-Yo & Akon) (New Edit) ['GN1100']
# Ain`t A Party (Feat. Harrison) (Radio Edit) ['GN2700', 'GN1100']
# Rock N Roll (Explicit Ver.) ['GN1000']
# The Fox ['GN0900']
# Supermassive Black Hole ['GN0900', 'GN1000']
# Slow Motion (Album Version) ['GN1300']
# Shut Up And Let Me Go ['GN1000']
# My Life Would Suck Without You ['GN0900']
# Obvious ['GN1000']
# Burn It To The Ground ['GN1500', 'GN1000']
# Down (Feat. Lil Wayne) ['GN1300']
# Time Is Running Out (Entourage 201) ['GN1500']
# Love Drunk ['GN1000']
# Blood Sugar ['GN2700', 'GN1100']
# Break Your Heart ['GN1300']

# %%
with open('C:/Users/YunSeog/Desktop/Melonplay/Hunchbrown-Melon-Playlist-Continuation/res/test.json', encoding = 'UTF-8') as f:
    test = json.load(f)

# %%
test_data = (pd.DataFrame(test))
test_data.head(30)
# Out:
#                         tags      id       plylst_title  \
# 0                         []   70107
# 1   [나만의Best3, 인디아티스트들의추천음악]    7461
# 2                     [드라이브]   90348
# 3                      [분위기]   58617
# 4                         []  102395
# 5                     [스트레스]   88862            노래방 안에서
# 6                         []   42586
# 7                       [사랑]  133975   봄바람과 듣고싶은 설레는 노래
# 8                         []   13244
# 9                       [겨울]  150444
# 10                        []   55399
# 11          [재즈, 기분전환, 뉴에이지]  135323  책읽으며 듣기좋은 잔잔 BGM♪
# 12          [매장음악, 드라이브, 여행]   95217
# 13                        []   16769
# 14                        []  134527
# 15            [봄, 기분전환, 경쾌한]  101357
# 16                      [추억]   41491
# 17                        []   43130     한여름의 센티멘탈 피아노.
# 18                        []  106340
# 19      [나는나를가장아낀다, 사랑, 자존감]   57072
