# %% [markdown]
# #### import 공간

# %%
import pandas as pd
import json
import random

# %% [markdown]
# ## genre_data

# %%
with open('C:/Users/YunSeog/Desktop/Melonplay/Hunchbrown-Melon-Playlist-Continuation/res/genre_gn_all.json', encoding = 'UTF-8') as f:
    genre_data = json.load(f)

# %%
print(pd.Series(genre_data))
# Out:
# GN0100       발라드
# GN0101    세부장르전체
# GN0102       '80
# GN0103       '90
# GN0104       '00
#            ...
# GN2900       뮤지컬
# GN2901    세부장르전체
# GN2902     국내뮤지컬
# GN2903     국외뮤지컬
# GN3000     크리스마스
# Length: 254, dtype: object

# %% [markdown]
# ## song_data

# %%
with open('C:/Users/YunSeog/Desktop/Melonplay/Hunchbrown-Melon-Playlist-Continuation/res/song_meta.json', encoding = 'UTF-8') as f:
    song_meta_data = json.load(f)

# %%
song_data = (pd.DataFrame(song_meta_data))

# %%
song_data.head(10)
# Out:
#      song_gn_dtl_gnr_basket issue_date  \
# 0                  [GN0901]   20140512
# 1          [GN1601, GN1606]   20080421
# 2                  [GN0901]   20180518
# 3          [GN1102, GN1101]   20151016
# 4          [GN1802, GN1801]   20110824
# 5                  [GN1701]   20100602
# 6  [GN1601, GN1602, GN1614]   20170208
# 7  [GN1601, GN1602, GN1614]   20190315
# 8                  [GN0301]   20070625
# 9          [GN0105, GN0101]   20170320
#
#                                           album_name  album_id  \
# 0                       불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
# 1                      Bach : Partitas Nos. 2, 3 & 4    376431
# 2                                                Hit   4698747
# 3  Feeling Right (Everything Is Nice) (Feat. Popc...   2644882
# 4                                            그남자 그여자   2008470
# 5                                        Bye, Lupita    911754
# 6    Sibelius: Symphony No. 2; Tapiola; Valse triste  10038397
# ...

# %% [markdown]
# ## trainee_data

# %%
with open('C:/Users/YunSeog/Desktop/Melonplay/Hunchbrown-Melon-Playlist-Continuation/res/train.json', encoding = 'UTF-8') as f:
    train_data = json.load(f)

# %%
trainee_data = (pd.DataFrame(train_data))

# %%
trainee_data
# Out:
#                                                      tags      id  \
# 0                                                     [락]   61281
# 1                                                [추억, 회상]   10532
# 2                                               [까페, 잔잔한]   76951
# 3       [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                                    [댄스]   27616
# ...                                                   ...     ...
# 115066               [록메탈, 밴드사운드, 록, 락메탈, 메탈, 락, extreme]  120325
# 115067                                               [일렉]  106976
# 115068             [담시, 가족, 눈물, 그리움, 주인공, 나의_이야기, 사랑, 친구]   11343
# 115069                      [잔잔한, 버스, 퇴근버스, Pop, 풍경, 퇴근길]  131982
# 115070                             [노래추천, 팝송추천, 팝송, 팝송모음]  100389
#
#                              plylst_title  \
# 0                                 여행같은 음악
# 1                                 요즘 너 말야
# 2                   편하게, 잔잔하게 들을 수 있는 곡.-
# ...

# %% [markdown]
# # 랜덤한 플레이리스트 선정
#
# ## 태그 출력
#
# ## 구성 곡 제목 및 아티스트, 장르 출력

# %%
lotto = random.randrange(0, len(trainee_data))
sample_songs = trainee_data.loc[lotto]['songs']
print("플레이리스트 제목 : "+trainee_data.loc[lotto]['plylst_title'])
print()
print("업데이트 날짜 :", trainee_data.loc[lotto]['updt_date'])
print()
print("태그 :", trainee_data.loc[lotto]['tags'])
print()
for song in sample_songs:
    temp = []
    for genre in song_data.loc[song]['song_gn_gnr_basket']:
        temp2 = genre_data[genre]
        temp.append(temp2)
    print("'"+song_data.loc[song]['song_name']+"'", "by",song_data.loc[song]['artist_name_basket'],temp)
# Out:
# 플레이리스트 제목 : 시원쌀쌀한 가을
#
# 업데이트 날짜 : 2017-11-30 12:53:38.000
#
# 태그 : ['선선한바람', '가을']
#
# 'DA DA DA (Feat. Hoody)' by ['로꼬'] ['랩/힙합']
# '보물섬 (Feat. HAN)' by ['millic (밀릭)'] ['인디음악', '일렉트로니카']
# 'Cigarette (Feat. Tablo, MISO)' by ['offonoff (오프온오프)'] ['R&B/Soul', '일렉트로니카']
# 'MOONSTRUCK X 김아일 & 오혁' by ['PEEJAY'] ['랩/힙합']
# 'Can`t (아직도 난)' by ['Golden'] ['R&B/Soul']
# 'rockstar (Feat. 21 Savage)' by ['Post Malone'] ['랩/힙합']
# 'Jasmine' by ['DPR LIVE'] ['랩/힙합']
# 'Cheapest Flight' by ['PREP'] ['R&B/Soul']
# 'Tiny Little Boy (Feat. DEAN)' by ['Rad Museum'] ['인디음악', 'R&B/Soul']
# '떠나기 전날에' by ['진보'] ['R&B/Soul']
# 'Pound Cake / Paris Morton Music 2 (Feat. JAY-Z)' by ['Drake'] ['랩/힙합']
# 'From Time (Feat. Jhen&#233; Aiko)' by ['Drake'] ['랩/힙합']
# '너의 몸에 벤 (Feat. Beenzino)' by ['벤 (VEN)'] ['인디음악', '랩/힙합']
# 'Habits (Stay High)' by ['Tove Lo'] ['POP']
# '서툰 기대' by ['폴킴', '디스토리'] ['발라드']
# 'PARACHUTE (Feat. 오혁 & Dok2)' by ['코드 쿤스트 (CODE KUNST)'] ['인디음악', '랩/힙합']
# ...
